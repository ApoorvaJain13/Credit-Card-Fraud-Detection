# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# Imported libraries for data visulisation and some general ones..

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Imported Data

# %%
df = pd.read_csv('Data.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# # Checking With basic info of Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
corr_df = pd.DataFrame(df.corr().transpose())
corr_df['Class']
# Out:
# Time     -0.012323
# V1       -0.101347
# V2        0.091289
# V3       -0.192961
# V4        0.133447
# V5       -0.094974
# V6       -0.043643
# V7       -0.187257
# V8        0.019875
# V9       -0.097733
# V10      -0.216883
# V11       0.154876
# V12      -0.260593
# V13      -0.004570
# V14      -0.302544
# V15      -0.004223
# V16      -0.196539
# V17      -0.326481
# V18      -0.111485
# V19       0.034783
# V20       0.020090
# V21       0.040413
# V22       0.000805
# V23      -0.002685
# V24      -0.007221
# V25       0.003308
# V26       0.004455
# V27       0.017580
# V28       0.009536
# Amount    0.005632
# Class     1.000000
# Name: Class, dtype: float64

# %% [markdown]
# # Exploratory Data analysis

# %%
plt.figure(figsize = (35,35))
sns.heatmap(corr_df, annot = True, cbar = True)

# %%
ax = sns.countplot (y = 'Class', data = df, palette="Set3", linewidth = 5)

plt.title('N. Of Frauds')

total = len(df['Class'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
sns.boxplot(x = 'Class', y = 'Time', data = df)

# %%
plt.figure(figsize = (50,50))


plt.subplot(4,4,1)
sns.boxplot(x = 'Class', y = 'V17', data = df)
plt.tight_layout()

plt.subplot(4,4,2)
sns.boxplot(x = 'Class', y = 'V2', data = df)
plt.tight_layout()


plt.subplot(4,4,3)
sns.boxplot(x = 'Class', y = 'V11', data = df)
plt.tight_layout()

plt.subplot(4,4,4)
sns.boxplot(x = 'Class', y = 'V21', data = df)
plt.tight_layout()

plt.subplot(4,4,5)
sns.boxplot(x = 'Class', y = 'V9', data = df)
plt.tight_layout()

plt.subplot(4,4,6)
sns.boxplot(x = 'Class', y = 'V20', data = df)
plt.tight_layout()

plt.subplot(4,4,7)
sns.boxplot(x = 'Class', y = 'V13', data = df)
plt.tight_layout()

plt.subplot(4,4,8)
sns.boxplot(x = 'Class', y = 'V24', data = df)
plt.tight_layout()

# %%
sns.boxplot(x = 'Class', y = 'Amount', data = df)

# %%
plt.figure(figsize = (20,5))
a = df['Time']
sns.distplot(a  , kde = True, rug = True)

# %%
plt.figure(figsize = (20,5))
a = df['Amount']
sns.distplot(a  , kde = True)

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# Scaling the Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x = df.values
scaled = scaler.fit_transform(x)
df = pd.DataFrame(scaled)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(30, axis = 1)
y = df[30]

# %% [markdown]
# TRAIN - TEST - SPLIT

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# MODEL CREATION

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Performance (Logistic Regression)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     85276
#          1.0       0.83      0.54      0.66       167
#
#     accuracy                           1.00     85443
#    macro avg       0.91      0.77      0.83     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[85257    19]
#  [   76    91]]

# %% [markdown]
# # KNN

# %% [markdown]
# TRAIN - TEST - SPLIT

# %%
data_2000 = df[:20000]
X = data_2000.drop(30, axis = 1)
y = data_2000[30]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# MODEL CREATION

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
error_rate = []

for i in range (1,40):
    
    knn = KNeighborsClassifier(n_neighbors= i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %% [markdown]
# # Performance (KNN)

# %%
plt.figure(figsize = (10,6))
plt.plot(error_rate, color = 'blue', ls = 'dashed', marker = 'o',markerfacecolor = 'red', markersize = 10)
plt.title ('Error Rate')
plt.xlabel ('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors= 2)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)
print (confusion_matrix(y_test, pred))
print ('\n')
print (classification_report(y_test, pred))
# Out:
# [[5973    1]
#  [   7   19]]
#
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      5974
#          1.0       0.95      0.73      0.83        26
#
#     accuracy                           1.00      6000
#    macro avg       0.97      0.87      0.91      6000
# weighted avg       1.00      1.00      1.00      6000

# %% [markdown]
# # Decision Tree

# %% [markdown]
# TRAIN - TEST -  SPLIT

# %%
X = df.drop(30, axis = 1)
y = df[30]
 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# MODEL CREATION

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
predictions = dtree.predict (X_test)

# %% [markdown]
# # Performance (Decision Tree)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print (confusion_matrix(y_test, predictions))
print ('\n')
print (classification_report(y_test, predictions))
# Out:
# [[85256    40]
#  [   34   113]]
#
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     85296
#          1.0       0.74      0.77      0.75       147
#
#     accuracy                           1.00     85443
#    macro avg       0.87      0.88      0.88     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# # Random Forrest Classification

# %% [markdown]
# TRAIN - TEST - SPLIT

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# MODEL CREATION

# %%
rfc = RandomForestClassifier(n_estimators = 200)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %% [markdown]
# # Performance (Random Forrest)

# %%
print (confusion_matrix(y_test, rfc_pred))
print ('\n')
print (classification_report(y_test, rfc_pred))
# Out:
# [[85290     6]
#  [   28   119]]
#
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     85296
#          1.0       0.95      0.81      0.88       147
#
#     accuracy                           1.00     85443
#    macro avg       0.98      0.90      0.94     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# TRAIN - TEST - SPLIT

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# MODEL CREATION

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pred = model.predict(X_test)

# %% [markdown]
# # Performance (SVM)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[85278    21]
#  [   24   120]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     85299
#          1.0       0.85      0.83      0.84       144
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.92      0.92     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# # Neural Network

# %% [markdown]
# TRAIN - TEST - SPLIT

# %%
X = df.drop(30, axis = 1).values
y = df[30].values


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# Model Creation

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, Dropout

# %%
model = Sequential()

model.add(Dense(30, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(20, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(10, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(5, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(1,activation = 'sigmoid'))


model.compile (optimizer = 'sgd',loss = 'binary_crossentropy')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 25)

# %%
model.fit(x = X_train, y = y_train, epochs = 100,validation_data= (X_test,y_test), callbacks = [early_stop], batch_size= 400)
# Out:
# Train on 199364 samples, validate on 85443 samples
# Epoch 1/100
# 199364/199364 [==============================] - 2s 8us/sample - loss: 0.2651 - val_loss: 0.0509
# Epoch 2/100
# 199364/199364 [==============================] - 1s 6us/sample - loss: 0.0860 - val_loss: 0.0170
# Epoch 3/100
# 199364/199364 [==============================] - 2s 11us/sample - loss: 0.0570 - val_loss: 0.0127
# Epoch 4/100
# 199364/199364 [==============================] - 2s 11us/sample - loss: 0.0462 - val_loss: 0.0120
# Epoch 5/100
# 199364/199364 [==============================] - 1s 6us/sample - loss: 0.0392 - val_loss: 0.0118
# Epoch 6/100
# 199364/199364 [==============================] - 1s 6us/sample - loss: 0.0356 - val_loss: 0.0118
# Epoch 7/100
# 199364/199364 [==============================] - 2s 10us/sample - loss: 0.0332 - val_loss: 0.0118
# Epoch 8/100
# 199364/199364 [==============================] - 2s 11us/sample - loss: 0.0306 - val_loss: 0.0118
# Epoch 9/100
# ...

# %% [markdown]
# # Performance (Neural Network)

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()

# %%
predictions = model.predict_classes(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print (classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     85297
#          1.0       0.00      0.00      0.00       146
#
#     accuracy                           1.00     85443
#    macro avg       0.50      0.50      0.50     85443
# weighted avg       1.00      1.00      1.00     85443
# C:\Users\Apoorva Jain\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print (confusion_matrix(y_test, predictions))
# Out:
# [[85297     0]
#  [  146     0]]

# %% [markdown]
# # Thank You
